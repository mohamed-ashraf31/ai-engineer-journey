# %%
import pandas as pd

# %%
data = {
    'country': ['USA', 'France', 'Italy', 'Spain', 'Egypt', 'Italy', 'Italy'],
    'points': [90, 95, 87, 92, 88, 50, 70],
    'price': [30, 50, 25, 40, 20, 30, 50]
}

reviews = pd.DataFrame(data,index=[0, 1, 2, 3, 4, 5, 6])
reviews
# Out:
#   country  points  price
# 0     USA      90     30
# 1  France      95     50
# 2   Italy      87     25
# 3   Spain      92     40
# 4   Egypt      88     20
# 5   Italy      50     30
# 6   Italy      70     50

# %%
reviews.iloc[1:3]

# %%
reviews.loc[0, 'country']
# Out:
# 'USA'

# %%
reviews.iloc[:3, 0]
# Out:
# 0       USA
# 1    France
# 2     Italy
# Name: country, dtype: str

# %%
reviews.loc[1,"country"]
# Out:
# 'France'

# %%
reviews.iloc[0:3, 2]
# Out:
# 0    30
# 1    50
# 2    25
# Name: price, dtype: int64

# %%
reviews.loc[:,"country"]
# Out:
# 0       USA
# 1    France
# 2     Italy
# 3     Spain
# 4     Egypt
# Name: country, dtype: str

# %%
reviews.set_index("price")
# Out:
#       country  points
# price
# 30        USA      90
# 50     France      95
# 25      Italy      87
# 40      Spain      92
# 20      Egypt      88

# %%
reviews.country=="Italy"
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: country, dtype: bool

# %%
reviews.loc[reviews.country=="Italy"]
# Out:
#   country  points  price
# 2   Italy      87     25

# %%
reviews.loc[(reviews.country=="Italy")& (reviews.points>=50)]
# Out:
#   country  points  price
# 2   Italy      87     25
# 5   Italy      50     30
# 6   Italy      70     50

# %%
reviews.loc[(reviews.country=="Italy")| (reviews.points>=50)]
# Out:
#   country  points  price
# 0     USA      90     30
# 1  France      95     50
# 2   Italy      87     25
# 3   Spain      92     40
# 4   Egypt      88     20
# 5   Italy      50     30
# 6   Italy      70     50

# %%
reviews.loc[reviews.points.isin([95, 70])]
# Out:
#   country  points  price
# 1  France      95     50
# 6   Italy      70     50

# %%
reviews.loc[reviews.price.notnull()]
# Out:
#   country  points  price
# 0     USA      90     30
# 1  France      95     50
# 2   Italy      87     25
# 3   Spain      92     40
# 4   Egypt      88     20
# 5   Italy      50     30
# 6   Italy      70     50

# %%
reviews['index_backwards'] = range(len(reviews), 0, -1)
reviews['index_backwards']
# Out:
# 0    7
# 1    6
# 2    5
# 3    4
# 4    3
# 5    2
# 6    1
# Name: index_backwards, dtype: int64
