# %%
import pandas as pd

# %%
people = {
    "first":["Mohamed", "Ramy", "Aya"],
    "last" :["Ashraf", "Ahmed", "Ali"], 
    "email":["mohamedashraf1@gmail.com", "ramyahmed1@gmail.com", "ayaali@gmail.com"] ,
}

# %%
df = pd.DataFrame(people)
df
# Out:
#      first    last                     email
# 0  Mohamed  Ashraf  mohamedashraf1@gmail.com
# 1     Ramy   Ahmed      ramyahmed1@gmail.com
# 2      Aya     Ali          ayaali@gmail.com

# %%
df.columns =["first_name", "last_name", "email"]

# %%
df
# Out:
#   first_name last_name                     email
# 0    Mohamed    Ashraf  mohamedashraf1@gmail.com
# 1       Ramy     Ahmed      ramyahmed1@gmail.com
# 2        Aya       Ali          ayaali@gmail.com

# %%
df.columns=df.columns.str.replace("_", " ")

# %%
df
# Out:
#   first name last name                     email
# 0    Mohamed    Ashraf  mohamedashraf1@gmail.com
# 1       Ramy     Ahmed      ramyahmed1@gmail.com
# 2        Aya       Ali          ayaali@gmail.com

# %%
df.columns = [x.lower() for x in df.columns]

# %%
df
# Out:
#   first name last name                     email
# 0    Mohamed    Ashraf  mohamedashraf1@gmail.com
# 1       Ramy     Ahmed      ramyahmed1@gmail.com
# 2        Aya       Ali          ayaali@gmail.com

# %%
df.rename(columns={"first name":"first"},inplace=True)

# %%
df
# Out:
#      first last name                     email
# 0  Mohamed    Ashraf  mohamedashraf1@gmail.com
# 1     Ramy     Ahmed      ramyahmed1@gmail.com
# 2      Aya       Ali          ayaali@gmail.com

# %%
df["email"]=df["email"].str.upper()

# %%
df
# Out:
#      first last name                     email
# 0  Mohamed    Ashraf  MOHAMEDASHRAF1@GMAIL.COM
# 1     Ramy     Ahmed      RAMYAHMED1@GMAIL.COM
# 2      Aya       Ali          AYAALI@GMAIL.COM

# %%
df.loc[2]= ("habeba","ashraf","habebaashraf@gmail.com")

# %%
df
# Out:
#      first last name                     email
# 0  Mohamed    Ashraf  MOHAMEDASHRAF1@GMAIL.COM
# 1     Ramy     Ahmed      RAMYAHMED1@GMAIL.COM
# 2   habeba    ashraf    habebaashraf@gmail.com

# %%
df.loc[2]= df.loc[2].str.upper()

# %%
df
# Out:
#      first last name                     email
# 0  Mohamed    Ashraf  MOHAMEDASHRAF1@GMAIL.COM
# 1     Ramy     Ahmed      RAMYAHMED1@GMAIL.COM
# 2   HABEBA    ASHRAF    HABEBAASHRAF@GMAIL.COM

# %%
df.loc[2]=df.loc[2].str.lower()

# %%
df
# Out:
#      first last name                     email
# 0  Mohamed    Ashraf  MOHAMEDASHRAF1@GMAIL.COM
# 1     Ramy     Ahmed      RAMYAHMED1@GMAIL.COM
# 2   habeba    ashraf    habebaashraf@gmail.com

# %%
df["email"]=df["email"].str.upper()

# %%
df
# Out:
#      first last name                     email
# 0  Mohamed    Ashraf  MOHAMEDASHRAF1@GMAIL.COM
# 1     Ramy     Ahmed      RAMYAHMED1@GMAIL.COM
# 2   habeba    ashraf    HABEBAASHRAF@GMAIL.COM

# %%
df.columns=df.columns.str.replace(" ","_")

# %%
df
# Out:
#      first last_name                     email
# 0  Mohamed    Ashraf  MOHAMEDASHRAF1@GMAIL.COM
# 1     Ramy     Ahmed      RAMYAHMED1@GMAIL.COM
# 2   habeba    ashraf    HABEBAASHRAF@GMAIL.COM

# %%
df.rename(columns={"first":"first_name"},inplace=True)

# %%
df.loc[2,"first_name"]="Habeba"

# %%
df
# Out:
#   first_name last_name                     email
# 0    Mohamed    Ashraf  MOHAMEDASHRAF1@GMAIL.COM
# 1       Ramy     Ahmed      RAMYAHMED1@GMAIL.COM
# 2     Habeba    ashraf    HABEBAASHRAF@GMAIL.COM

# %%
df["email"].apply(len)
# Out:
# 0    24
# 1    20
# 2    22
# Name: email, dtype: int64

# %%
def update_email(email):
    return email.lower()

# %%
df["email"]=df["email"].apply(update_email)

# %%
df
# Out:
#   first_name last_name                     email
# 0    Mohamed    Ashraf  mohamedashraf1@gmail.com
# 1       Ramy     Ahmed      ramyahmed1@gmail.com
# 2     Habeba    ashraf    habebaashraf@gmail.com

# %%
df["email"]=df["email"].apply(lambda x: x.upper())

# %%
df
# Out:
#   first_name last_name                     email
# 0    Mohamed    Ashraf  MOHAMEDASHRAF1@GMAIL.COM
# 1       Ramy     Ahmed      RAMYAHMED1@GMAIL.COM
# 2     Habeba    ashraf    HABEBAASHRAF@GMAIL.COM
