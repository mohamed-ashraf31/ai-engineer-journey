# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/moham/Desktop/ai-engineer-journey/pandas-practice/students_data.csv')
df.head()
# Out:
#    student_id     name  age                   major   gpa    city nationality  \
# 0        1001  Mohamed   19  Electrical Engineering  2.74   Izmir    Lebanese
# 1        1002    Ahmed   18    Software Engineering  2.42   Izmir      Syrian
# 2        1003      Ali   22            Data Science  2.53  Ankara    Lebanese
# 3        1004     Omar   21            Data Science  3.87    Giza    Egyptian
# 4        1005   Hassan   21             Mathematics  3.30   Izmir    Egyptian
#
#    study_hours_per_week  scholarship  graduation_year
# 0                    25        False             2028
# 1                    36         True             2029
# 2                     6         True             2029
# 3                    12         True             2029
# 4                    28         True             2026

# %%
df.age.describe()
# Out:
# count    30.000000
# mean     20.666667
# std       2.056668
# min      18.000000
# 25%      19.000000
# 50%      21.000000
# 75%      22.000000
# max      25.000000
# Name: age, dtype: float64

# %%
df.city.describe()
# Out:
# count        30
# unique        7
# top       Izmir
# freq          7
# Name: city, dtype: object

# %%
df.age.mean()
# Out:
# np.float64(20.666666666666668)

# %%
df.city.unique()
# Out:
# <StringArray>
# ['Izmir', 'Ankara', 'Giza', 'Alexandria', 'Cairo', 'Istanbul', 'Bursa']
# Length: 7, dtype: str

# %%
df.city.value_counts()
# Out:
# city
# Izmir         7
# Alexandria    7
# Cairo         4
# Istanbul      4
# Giza          3
# Bursa         3
# Ankara        2
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    student_id     name  age                   major   gpa    city nationality  \
# 0        1001  Mohamed   19  Electrical Engineering  2.74   Izmir    Lebanese
# 1        1002    Ahmed   18    Software Engineering  2.42   Izmir      Syrian
# 2        1003      Ali   22            Data Science  2.53  Ankara    Lebanese
# 3        1004     Omar   21            Data Science  3.87    Giza    Egyptian
# 4        1005   Hassan   21             Mathematics  3.30   Izmir    Egyptian
#
#    study_hours_per_week  scholarship  graduation_year
# 0                    25        False             2028
# 1                    36         True             2029
# 2                     6         True             2029
# 3                    12         True             2029
# 4                    28         True             2026

# %%
age_mean = df.age.mean()
df.age.map(lambda x: x-age_mean)
# Out:
# 0    -1.666667
# 1    -2.666667
# 2     1.333333
# 3     0.333333
# 4     0.333333
# 5    -0.666667
# 6    -1.666667
# 7    -1.666667
# 8     3.333333
# 9    -2.666667
# 10   -2.666667
# 11   -1.666667
# 12    0.333333
# 13    0.333333
# 14   -2.666667
# 15    0.333333
# 16    3.333333
# 17    0.333333
# 18    4.333333
# 19    1.333333
# 20   -2.666667
# 21   -0.666667
# 22    3.333333
# 23    2.333333
# 24    1.333333
# 25   -0.666667
# 26    0.333333
# 27    2.333333
# 28   -1.666667
# 29   -1.666667
# Name: age, dtype: float64

# %%
df
# Out:
#     student_id     name  age                   major   gpa        city  \
# 0         1001  Mohamed   19  Electrical Engineering  2.74       Izmir
# 1         1002    Ahmed   18    Software Engineering  2.42       Izmir
# 2         1003      Ali   22            Data Science  2.53      Ankara
# 3         1004     Omar   21            Data Science  3.87        Giza
# 4         1005   Hassan   21             Mathematics  3.30       Izmir
# 5         1006  Youssef   20            Data Science  3.22  Alexandria
# 6         1007    Karim   19    Software Engineering  2.34       Izmir
# 7         1008  Mahmoud   19  Electrical Engineering  3.46  Alexandria
# 8         1009   Fatima   24             Mathematics  2.33      Ankara
# 9         1010     Nour   18    Software Engineering  2.76       Cairo
# 10        1011     Sara   18  Electrical Engineering  3.98       Cairo
# 11        1012   Mariam   19    Software Engineering  3.28       Izmir
# ...

# %%
df.age.mean()
# Out:
# np.float64(20.666666666666668)

# %%
age_mean=df.age.mean()
df.age.map(lambda x: x-age_mean)
# Out:
# 0    -1.666667
# 1    -2.666667
# 2     1.333333
# 3     0.333333
# 4     0.333333
# 5    -0.666667
# 6    -1.666667
# 7    -1.666667
# 8     3.333333
# 9    -2.666667
# 10   -2.666667
# 11   -1.666667
# 12    0.333333
# 13    0.333333
# 14   -2.666667
# 15    0.333333
# 16    3.333333
# 17    0.333333
# 18    4.333333
# 19    1.333333
# 20   -2.666667
# 21   -0.666667
# 22    3.333333
# 23    2.333333
# 24    1.333333
# 25   -0.666667
# 26    0.333333
# 27    2.333333
# 28   -1.666667
# 29   -1.666667
# Name: age, dtype: float64

# %%
df.apply(lambda row: row*)
